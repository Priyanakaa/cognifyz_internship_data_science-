# %% [markdown]
# # LEVEL-1 : TASK-1

# %% [markdown]
# # TASK : DATA EXPLORATION AND PREPROCESSING

# %% [raw]
# Explore the dataset and identify the number of rows and columns.

# %% [raw]
# In Python with pandas, we can explore our CSV dataset as follows:
# Load the dataset using pandas.read_csv('file.csv').
# For displaying first few rows we use .head() attribute.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"cognifyzdataset.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [raw]
# To identify the number of rows and columns:
# Use the .shape attribute to find the number of rows and columns.

# %%
print("No.of rows and columns:",df.shape)
# Out:
# No.of rows and columns: (9551, 21)

# %% [raw]
# To find the statistical summary of the dataset:
# Use the .describe() method to get a description that includes statistical summaries for numerical columns.

# %%
print("Statistical summary of numerical columns:")
print(df.describe())
# Out:
# Statistical summary of numerical columns:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [raw]
# Check for missing values in each column and handle them accordingly.
# We use .isnull().sum() function to find the total no.of missing values

# %%
print("No.of missing values:")
print(df.isnull().sum())
# Out:
# No.of missing values:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [raw]
# To handle missing values, we have several options:
# Drop rows with any missing values: df.dropna(inplace=True)
# Drop columns with any missing values: df.dropna(axis=1, inplace=True)

# %%
df.dropna(subset=["Cuisines"],inplace=True)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
print("No.of missing values in each column:")
print(df.isnull().sum())
df.to_csv('C:/Users/Geeth/Downloads/contacts.csv')
# Out:
# No.of missing values in each column:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
dt=df.duplicated().sum()
print(f"No.of duplicated rows are {dt}")
# Out:
# No.of duplicated rows are 0

# %% [raw]
# We use .info() to find the information like datatype and missing values in columns.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [raw]
# Analyze the distribution of the target variable ("Aggregate rating") and
# identify any class imbalances.

# %%
tar="Aggregate rating"

# %%
print(df[tar].describe())
# Out:
# count    9542.000000
# mean        2.665238
# std         1.516588
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %% [raw]
# A boxplot is a standardized way of displaying the distribution of data based on a five-number summary:
# minimum, first quartile (Q1), median, third quartile (Q3), and maximum.
# In Python, you can create a boxplot using the matplotlib or seaborn libraries, which integrate well with pandas.
# Here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"cognifyzdataset.csv")
tar="Aggregate rating"
plt.figure(figsize=(8,5))
sns.boxplot(x=df[tar])
plt.title("BOX PLOT")
plt.xlabel("Aggregate Rating")
plt.show()

# %% [raw]
# In pandas, you can create a histogram using the .hist() method of a DataFrame.
# This method is used to plot the frequency distribution of numerical data.
# This will create a histogram of the specified column. We can customize it by passing additional parameters like bins (to specify the number of bins), grid (to show or hide the grid), figsize (to specify the size of the figure), and more.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df[tar],bins=30,kde=True,color="blue")
plt.title("HISTOGRAM")
plt.xlabel("Aggregate Rating")
plt.ylabel("Frequency")
plt.show()

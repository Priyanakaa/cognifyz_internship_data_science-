# %% [markdown]
# # LEVEL-1 : TASK- 3

# %% [markdown]
# # TASK : GEOSPATIAL ANALYSIS

# %%
#pip install shapely geopandas matplotlib
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/51.5 kB ? eta -:--:--
#      --------------- ---------------------- 20.5/51.5 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 51.5/51.5 kB 529.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.4 MB 3.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/1.4 MB 2.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.4 MB 2.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.4 MB 2.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 2.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 2.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.4 MB 2.4 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.4 MB 2.2 MB/s eta 0:00:01
# ...

# %% [raw]
# Visualize the locations of restaurants on a map using latitude and longitude information.

# %% [raw]
# To visualize restaurant locations on a map using GeoDataFrames in Geopandas, we can follow these steps in your Python code:
# - Import Libraries: Import Geopandas and other necessary libraries.
# - Create a GeoDataFrame: Load your data into a GeoDataFrame. If your data is in a CSV file with ‘latitude’ and ‘longitude’ columns, you can do it like this:
# df = gpd.read_file('your_file.csv')
# gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
# - Plot the Map: Use the plot method of the GeoDataFrame to visualize the data.
# gdf.plot(marker='o', color='red', markersize=5)
# plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"cognifyzdataset.csv")
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
gdf=gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df.Longitude,df.Latitude))
world=gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
gdf.plot(ax=world.plot("continent",legend=True,figsize=(18,15)),marker="o")
plt.show()
# Out:
# C:\Users\Geeth\AppData\Local\Temp\ipykernel_2084\1283972968.py:10: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world=gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %% [raw]
# Analyze the distribution of restaurants across different cities or countries

# %% [raw]
# One of the best ways to explore the distribution of a categorical variable in Python is by using a count plot, which shows the counts of observations in each category. The seaborn library has a countplot function that is specifically designed for this purpose and works well with pandas DataFrames.
# This will create a bar chart with the count of each unique value in the specified column.

# %%
plt.figure(figsize=(8,5))
sns.countplot(y=df["City"],order=df["City"].value_counts().head(20).index)
plt.title("DISTRIBUTION OF RESTAURANTS ACROSS CITIES")
plt.xlabel("No.of Restaurants")
plt.ylabel("No.of cities")
plt.show()

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.6 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 645.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.9 MB 960.0 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/10.9 MB 1.3 MB/s eta 0:00:09
#     --------------------------------------- 0.2/10.9 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.2/10.9 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/10.9 MB 1.2 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/10.9 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/10.9 MB 1.2 MB/s eta 0:00:10
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"cognifyzdataset.csv")
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Rating text'] = label_encoder.fit_transform(df['Rating text'])
df.head()
correlation_matrix = df[['Latitude', 'Longitude', 'Rating text']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
#              Latitude  Longitude  Rating text
# Latitude     1.000000   0.043207    -0.129447
# Longitude    0.043207   1.000000    -0.181466
# Rating text -0.129447  -0.181466     1.000000

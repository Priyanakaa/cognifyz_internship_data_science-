# %% [markdown]
# # LEVEL-2 : TASK-2

# %% [markdown]
# # TASK : PRICE RANGE ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"cognifyzdataset.csv")

# %% [raw]
# Determine the most common price range among all the restaurants.

# %% [raw]
# To find out the most common price range we should use .mode() attribute as we may have many modes too we used [0] because we took the top most common price range .

# %%
most_common_price_range = df['Price range'].mode()[0]
print(f"Most Common Price Range: {most_common_price_range}")
# Out:
# Most Common Price Range: 1

# %% [raw]
# Calculate the average rating for each price range.

# %% [raw]
# To calculate the average rating we can use .mean() . We also rounded off the answer to three decimal digits .

# %%
avg_rating_by_price_range = df.groupby('Price range')['Aggregate rating'].mean()
print("Average rating for each price range:")
print(round(avg_rating_by_price_range,3))
# Out:
# Average rating for each price range:
# Price range
# 1    2.000
# 2    2.941
# 3    3.683
# 4    3.818
# Name: Aggregate rating, dtype: float64

# %% [raw]
# Identify the color that represents the highest average rating among different price ranges.

# %% [raw]
# To perform the above task we got the highest average rating by using idxmax().
# For a Pandas Series, such as a single column, idxmax() returns the row label (index) of the maximum value.
# Remember that idxmax() returns the first occurrence of the maximum value. If multiple rows have the same maximum value, it returns the first one encountered in the DataFrame or Series.After this we represented average rating by pink color and highest rating by yellow color.

# %%
highest_avg_rating_color = avg_rating_by_price_range.idxmax()
plt.bar(avg_rating_by_price_range.index, avg_rating_by_price_range, color='pink')
plt.bar(highest_avg_rating_color, avg_rating_by_price_range[highest_avg_rating_color], color='yellow')
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
plt.title('Average Rating by Price Range')
plt.show()

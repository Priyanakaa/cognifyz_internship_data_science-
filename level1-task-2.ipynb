# %% [markdown]
# # LEVEL-1 : TASK-2

# %% [markdown]
# # TASK: DESCRIPTIVE ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"cognifyzdataset.csv")
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [raw]
# Calculate basic statistical measures (mean, median, standard deviation, etc.) for numerical columns.

# %% [raw]
# We use .describe() attribute for statistical data like mean,standard deviation etc.

# %%
df[["Average Cost for two","Price range","Aggregate rating","Votes"]].describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [raw]
# Explore the distribution of categorical variables like "Country Code", "City", and "Cuisines".

# %% [raw]
# One of the best ways to explore the distribution of a categorical variable in Python is by using a count plot, which shows the counts of observations in each category. The seaborn library has a countplot function that is specifically designed for this purpose and works well with pandas DataFrames.
# This will create a bar chart with the count of each unique value in the specified column.

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Country Code",data=df,palette="cividis")
plt.title("DISTRIBUTION OF RESTAURANTS BY COUNTRY CODE")
plt.xlabel("Country Code")
plt.ylabel("No.of restaurants")
plt.show()
# Out:
# C:\Users\Geeth\AppData\Local\Temp\ipykernel_9308\685136408.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Country Code",data=df,palette="cividis")

# %%
top_countries=df["Country Code"].value_counts().head()
print("Top 5 countries with highest no.of restaurants")
print(top_countries)
# Out:
# Top 5 countries with highest no.of restaurants
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="City",data=df,order=df["City"].value_counts().head(20).index)
plt.title("DISTRIBUTION OF RESTAURANTS BY CITY")
plt.xlabel("City")
plt.ylabel("No.of Restaurants")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,6))
cuisines_count=df["Cuisines"].value_counts()
cuisines_count.head(25).plot(kind="bar",color=sns.color_palette("Set3",15))
plt.title("TOP 20 CUISINES WITH HIGHEST NUMBER OF RESTAURANTS")
plt.xlabel("Cuisine")
plt.ylabel("No.of Restaurants")
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Identify the top cuisines and cities with the highest number of restaurants.

# %% [raw]
# The value_counts() method in pandas is used to count the unique values in a column and return a Series with the counts.
# The results are sorted by descending order, so the most frequent values appear first.

# %%
top_cities=df["City"].value_counts().head(10)
print("Top 10 cities with highest no.of restaurants")
print(top_cities)
# Out:
# Top 10 cities with highest no.of restaurants
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
top_cuisines=cuisines_count.head(10)
print("Top 10 cuisines with highest no.of restaurants")
print(top_cuisines)
# Out:
# Top 10 cuisines with highest no.of restaurants
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64
